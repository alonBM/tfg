# %% [markdown]
# # 5. Selección del modelo para los datos
#
# En esta parte se debe de elegir un modelo de ML, entrenar y evaluar el set de entrenamiento. Hay varias técnicas que se pueden aplicar aquí, como la creación de un conjunto de validación a partir del conjunto de datos, realizar un cambio de modelo ,ajustar ciertos parámetros, combinar modelos, etc.
