# %% [markdown]
# # 4. Trabajar estadísticamente con los datos
#
# En esta parte se buscan correlaciones entre los datos, se evaluan y definen métricas, etc. También se crean diferentes conjuntos o nuevas combinaciones de atributos. Va muy legada al procesado de datos, ya que según las nuevas relaciones que encontremos, será necesario o no volver a procesar los datos.
