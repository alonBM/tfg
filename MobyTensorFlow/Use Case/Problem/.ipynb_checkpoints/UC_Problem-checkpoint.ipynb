# %% [markdown]
# # Problema a abordar (Pendiente)
#
# La movilidad es uno de los ámbitos en los que la IA tiene mucho que decir.
#
# ## Movilidad
# * Distintos tipos de posibles datos: gps, cdr, etc.
# * Aplicaciones que se le puede dar a estos datos.
#
#
# ## Tensorflow 2.0
#
# ![Tensorflow 2](../../Images/tf2.png)
#
# * Salio a mediados de 2019. Mucho más flexible y facil de usar
# * Google ha declarado 'deprecated' la versión 1.0
# * Nuevas características que facilitan mucho su uso
#
# ## Redes neuronales
#
# * Como funcionan
#
#
# ## Datos a utilizar
#
# * Se utilizaran los datos GPS de GeoLife para predecir cuando una persona está en casa o no.
