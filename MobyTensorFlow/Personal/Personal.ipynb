# %% [markdown]
# # Proyecto
# Implementación y caso práctico de Tensorflow en Python
# # Grado
# Grado en ingeniería de computadores
# # Nombre
# Humberto Alonso Bertea Matencio
# # Correo
# humberto.bertea@edu.uah.es
# # Teléfono
# 636073082
